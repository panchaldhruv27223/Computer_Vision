# %%
pip install opencv-contrib-python
# Out:
# ...
#    ---------------------------------------- 0.0/45.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/45.3 MB 2.0 MB/s eta 0:00:23
#    ---------------------------------------- 0.1/45.3 MB 1.2 MB/s eta 0:00:40
#    ---------------------------------------- 0.2/45.3 MB 1.7 MB/s eta 0:00:26
#    ---------------------------------------- 0.2/45.3 MB 1.7 MB/s eta 0:00:27
#    ---------------------------------------- 0.4/45.3 MB 1.9 MB/s eta 0:00:24
#    ---------------------------------------- 0.5/45.3 MB 2.2 MB/s eta 0:00:21
#     --------------------------------------- 0.7/45.3 MB 2.5 MB/s eta 0:00:19
#     --------------------------------------- 0.8/45.3 MB 2.7 MB/s eta 0:00:17
#     --------------------------------------- 1.0/45.3 MB 2.9 MB/s eta 0:00:16
#    - -------------------------------------- 1.2/45.3 MB 3.1 MB/s eta 0:00:15
#    - -------------------------------------- 1.3/45.3 MB 3.0 MB/s eta 0:00:15
# ...

# %%
import cv2

# %%
for i in dir(cv2):
    if "EVENT" in i :
        print(i)
# Out:
# EVENT_FLAG_ALTKEY
# EVENT_FLAG_CTRLKEY
# EVENT_FLAG_LBUTTON
# EVENT_FLAG_MBUTTON
# EVENT_FLAG_RBUTTON
# EVENT_FLAG_SHIFTKEY
# EVENT_LBUTTONDBLCLK
# EVENT_LBUTTONDOWN
# EVENT_LBUTTONUP
# EVENT_MBUTTONDBLCLK
# EVENT_MBUTTONDOWN
# EVENT_MBUTTONUP
# EVENT_MOUSEHWHEEL
# EVENT_MOUSEMOVE
# EVENT_MOUSEWHEEL
# EVENT_RBUTTONDBLCLK
# EVENT_RBUTTONDOWN
# EVENT_RBUTTONUP

# %%
pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.6 MB 960.0 kB/s eta 0:00:41
#    ---------------------------------------- 0.1/38.6 MB 1.4 MB/s eta 0:00:28
#    ---------------------------------------- 0.2/38.6 MB 1.5 MB/s eta 0:00:26
#    ---------------------------------------- 0.3/38.6 MB 1.8 MB/s eta 0:00:22
#    ---------------------------------------- 0.4/38.6 MB 1.8 MB/s eta 0:00:22
#     --------------------------------------- 0.6/38.6 MB 2.4 MB/s eta 0:00:16
#     --------------------------------------- 0.7/38.6 MB 2.8 MB/s eta 0:00:14
#     --------------------------------------- 0.9/38.6 MB 2.7 MB/s eta 0:00:14
#    - -------------------------------------- 1.1/38.6 MB 3.0 MB/s eta 0:00:13
#    - -------------------------------------- 1.2/38.6 MB 2.9 MB/s eta 0:00:13
#    - -------------------------------------- 1.3/38.6 MB 3.0 MB/s eta 0:00:13
# ...

# %%
import cv2
import numpy
import matplotlib.pyplot as plt

# %%
img = cv2.imread("80457700.jpg")
img.shape
# Out:
# (4058, 7300, 3)

# %%
window = "window1"
def drawFunc(event,x,y,flags,params):
    if event == cv2.EVENT_LBUTTONDBLCLK:
        cv2.circle(img,(x,y),100,(255,0,0),10)
    
cv2.namedWindow(window, cv2.WINDOW_NORMAL)
cv2.setMouseCallback(window,drawFunc)

while 1 :
    key = cv2.waitKey(1)
    if key == 27 :
        break
    
    cv2.imshow(window,img)
    
cv2.destroyAllWindows()

# %%
img = cv2.imread("80457700.jpg")
img.shape
# Out:
# (4058, 7300, 3)

# %%
ix = -1
iy = -1
mode = True
drawing = False
def drawingShapes(event,x,y,flag,param):
    global ix,iy,mode,drawing
    if event == cv2.EVENT_LBUTTONDOWN:
        drawing = True 
        ix,iy = x,y
        
    elif event == cv2.EVENT_MOUSEMOVE:
        if drawing == True :
            if mode == True :
                cv2.rectangle(img,(ix,iy),(x,y),(0,255,0),-1)
            else :
                cv2.circle(img,(x,y),5,(0,255,0),10)
                
            
    elif event == cv2.EVENT_LBUTTONUP:
        drawing = False
        if mode == True:
            cv2.rectangle(img,(ix,iy),(x,y),(0,255,0),-1)
        else :
            cv2.circle(img,(x,y),100,(0,255,0),10)

# %%
window = "Mouce"
cv2.namedWindow(window, cv2.WINDOW_NORMAL)
cv2.setMouseCallback(window,drawingShapes)

while 1 :
    key = cv2.waitKey(1)
    if key == ord("m"):
        mode = not mode
    if key == ord("q"):
        break
    
    cv2.imshow(window,img)
    
cv2.destroyWindow(window)
cv2.destroyAllWindows()

# %%
mode = True

# %%
mode = not mode

# %%
mode
# Out:
# True

# %%
import numpy as np
import cv2 as cv
drawing = False # true if mouse is pressed
mode = True # if True, draw rectangle. Press 'm' to toggle to curve
ix,iy = -1,-1

# mouse callback function
def draw_circle(event,x,y,flags,param):
    global ix,iy,drawing,mode
    if event == cv.EVENT_LBUTTONDOWN:
        drawing = True
        ix,iy = x,y
    elif event == cv.EVENT_MOUSEMOVE:
        if drawing == True:
            if mode == True:
                cv.rectangle(img,(ix,iy),(x,y),(0,255,0),-1)
            else:
                cv.circle(img,(x,y),5,(0,0,255),-1)
    elif event == cv.EVENT_LBUTTONUP:
        drawing = False
        if mode == True:
            cv.rectangle(img,(ix,iy),(x,y),(0,255,0),-1)
        else:
            cv.circle(img,(x,y),5,(0,0,255),-1)

# %%
img = np.zeros((512,512,3), np.uint8)
cv.namedWindow('image')
cv.setMouseCallback('image',draw_circle)
while(1):
    cv.imshow('image',img)
    k = cv.waitKey(1) & 0xFF
    if k == ord('m'):
        mode = not mode
    elif k == 27:
        break
cv.destroyAllWindows()
